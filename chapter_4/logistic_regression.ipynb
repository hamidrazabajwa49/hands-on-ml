# %% [markdown]
# # Logistic Regression
# **Chapter 4 — Hands-On ML**
#
# Covers: binary classification with sigmoid output, decision boundary, probability curve.
#
# Dataset: Iris — classifying *Iris Virginica* vs rest using petal width.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Dataset

# %%
iris = datasets.load_iris()
X = iris['data'][:, 3:]          # petal width only
y = (iris['target'] == 2).astype(int)  # 1 = Virginica and 0 = other
print('X shape:', X.shape, '| y unique:', np.unique(y))

# %% [markdown]
# ## 2. Train Logistic Regression

# %%
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X, y)
print('Intercept:', log_reg.intercept_)
print('Coefficient:', log_reg.coef_)

# %% [markdown]
# ## 3. Decision Boundary & Probability Curve

# %%
X_new = np.linspace(0, 3, 1000).reshape(-1, 1)
y_proba = log_reg.predict_proba(X_new)

plt.figure(figsize=(9, 4))
plt.plot(X_new, y_proba[:, 1], 'g-', linewidth=2, label='Iris Virginica (p)')
plt.plot(X_new, y_proba[:, 0], 'b--', linewidth=2, label='Not Virginica (p)')
plt.axvline(x=X_new[np.where(y_proba[:, 0] < 0.5)[0][0]], color='k', linestyle=':', label='Decision boundary')
plt.xlabel('Petal Width (cm)'); plt.ylabel('Probability')
plt.title('Logistic Regression — Probability Curves')
plt.legend(); plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## 4. Predictions

# %%
samples = np.array([[1.7], [1.5]])
print('Predictions:', log_reg.predict(samples))
print('Probabilities:\n', log_reg.predict_proba(samples))
